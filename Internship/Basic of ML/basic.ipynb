# %% [markdown]
# ## 1. VARIABLES AND DATA TYPES

# %%
name = "Ubaid"                 # string
age = 20                       # integer
marks = 85.5                   # float
passed = True                  # boolean

print("===== STUDENT INFORMATION =====")
print("Name:", name)
print("Age:", age)
print("Marks:", marks)
print("Passed:", passed)
# Out:
# ===== STUDENT INFORMATION =====
# Name: Ubaid
# Age: 20
# Marks: 85.5
# Passed: True

# %% [markdown]
# ## 2. CONDITIONAL STATEMENTS

# %%
print("\n===== CONDITION =====")

if marks >= 80:
    grade = "A"
elif marks >= 70:
    grade = "B"
elif marks >= 60:
    grade = "C"
elif marks >= 50:
    grade = "D"
else:
    grade = "F"

print("Grade:", grade)

if passed:
    print("Student has passed.")
else:
    print("Student has failed.")
# Out:
# ===== CONDITION =====
# Grade: A
# Student has passed.

# %% [markdown]
# ## 3. Loops

# %%
print("\n===== LOOP =====")

subjects = ["Python", "Math", "AI", "Database"]

for subject in subjects:
    print("Subject:", subject)

print("Numbers from 1 to 5:")
for i in range(1, 6):
    print(i)

# while loop
count = 1
while count <= 3:
    print("While loop:", count)
    count += 1
# Out:
# ===== LOOP =====
# Subject: Python
# Subject: Math
# Subject: AI
# Subject: Database
# Numbers from 1 to 5:
# 1
# 2
# 3
# 4
# 5
# While loop: 1
# While loop: 2
# While loop: 3

# %% [markdown]
# ## 4.Functions

# %%
def calculate_average(marks_list):
    """Calculate average marks."""
    return sum(marks_list) / len(marks_list)

def show_result(student_name, average):
    """Display result using a function."""
    if average >= 50:
        return f"{student_name} passed with average {average:.2f}"
    else:
        return f"{student_name} failed with average {average:.2f}"

# Name define karein taaki error na aaye
name = "Ali"  
student_marks = [85, 78, 90, 88]
average = calculate_average(student_marks)

print("\n===== FUNCTIONS =====")
print("Average:", average)
print(show_result(name, average))
# Out:
# ===== FUNCTIONS =====
# Average: 85.25
# Ali passed with average 85.25

# %% [markdown]
# ## 5.List and dictionary comprehensions

# %%
print("\n===== LIST COMPREHENSION =====")

numbers = [1, 2, 3, 4, 5]
squares = [number ** 2 for number in numbers]

print("Numbers:", numbers)
print("Squares:", squares)


# 6. DICTIONARY COMPREHENSION
print("\n===== DICTIONARY COMPREHENSION =====")

marks_dict = {
    subject: mark
    for subject, mark in zip(subjects, student_marks)
}

print("Marks Dictionary:", marks_dict)
# Out:
# ===== LIST COMPREHENSION =====
# Numbers: [1, 2, 3, 4, 5]
# Squares: [1, 4, 9, 16, 25]
#
# ===== DICTIONARY COMPREHENSION =====
# Marks Dictionary: {'Python': 85, 'Math': 78, 'AI': 90, 'Database': 88}

# %% [markdown]
# ## 7. EXCEPTION HANDLING

# %%
print("\n===== EXCEPTION HANDLING =====")

try:
    user_number = int("100")
    result = 100 / user_number
    print("Result:", result)

except ValueError:
    print("Please enter a valid number.")

except ZeroDivisionError:
    print("Cannot divide by zero.")

finally:
    print("Exception handling completed.")
# Out:
# ===== EXCEPTION HANDLING =====
# Result: 1.0
# Exception handling completed.

# %% [markdown]
# ## 8. FILE HANDLING

# %%
print("\n===== FILE HANDLING =====")

file_name = "student_result.txt"

# Write data to a file
with open(file_name, "w") as file:
    file.write("Student Result\n")
    file.write(f"Name: {name}\n")
    file.write(f"Average: {average:.2f}\n")
    file.write(f"Grade: {grade}\n")

print("Data written to", file_name)

# Read data from the file
with open(file_name, "r") as file:
    data = file.read()

print("File Data:")
print(data)
# Out:
# ===== FILE HANDLING =====
# Data written to student_result.txt
# File Data:
# Student Result
# Name: Ali
# Average: 85.25
# Grade: A

# %% [markdown]
# ## 9. CLASSES AND OBJECTS

# %%
print("===== CLASSES AND OBJECTS =====")


class Student:
    def __init__(self, name, age, marks):
        self.name = name
        self.age = age
        self.marks = marks

    def get_average(self):
        return sum(self.marks) / len(self.marks)

    def display(self):
        print("Name:", self.name)
        print("Age:", self.age)
        print("Marks:", self.marks)
        print("Average:", round(self.get_average(), 2))
# Out:
# ===== CLASSES AND OBJECTS =====

# %%
student1 = Student("Ali", 21, [80, 75, 90, 85])

student1.display()
# Out:
# Name: Ali
# Age: 21
# Marks: [80, 75, 90, 85]
# Average: 82.5

# %% [markdown]
# ## 10. MODULES AND PACKAGES

# %%
print("\n===== MODULES AND PACKAGES =====")

# 'math' is a Python standard library module.
import math

number = 25
print("Square root of 25:", math.sqrt(number))

# 'datetime' is another standard library module.
from datetime import datetime

current_time = datetime.now()
print("Current date and time:", current_time)
# Out:
# ===== MODULES AND PACKAGES =====
# Square root of 25: 5.0
# Current date and time: 2026-08-12 12:42:20.065245
