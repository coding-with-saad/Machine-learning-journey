# %%
# Data manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Display all columns
pd.set_option("display.max_columns", None)

# Better looking plots
plt.style.use("ggplot")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 7
#       3 import numpy as np
#       4
#       5 # Visualization
#       6 import matplotlib.pyplot as plt
# ----> 7 import seaborn as sns
#       8
#       9 # Display all columns
#      10 pd.set_option("display.max_columns", None)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\seaborn\__init__.py:5
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
# ----> 5 from .relational import *  # noqa: F401,F403
#       6 from .regression import *  # noqa: F401,F403
#       7 from .categorical import *  # noqa: F401,F403
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\seaborn\relational.py:21
#      13 from .utils import (
#      14     adjust_legend_subtitles,
#      15     _default_color,
#    (...)     18     _scatter_legend_artist,
#      19 )
#      20 from ._compat import groupby_apply_include_groups
# ---> 21 from ._statistics import EstimateAggregator, WeightedAggregator
#      22 from .axisgrid import FacetGrid, _facet_docs
#      23 from ._docstrings import DocstringComponents, _core_docs
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\seaborn\_statistics.py:32
#      30 import pandas as pd
#      31 try:
# ---> 32     from scipy.stats import gaussian_kde
#      33     _no_scipy = False
#      34 except ImportError:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\scipy\stats\__init__.py:600
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)    595
#     596 """  # noqa: E501
#     598 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     599                                DegenerateDataWarning, FitError)
# --> 600 from ._stats_py import *
#     601 from ._variation import variation
#     602 from .distributions import *
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\scipy\stats\_stats_py.py:50
#      46 import scipy.special as special
#      47 # Import unused here but needs to stay until end of deprecation periode
#      48 # See https://github.com/scipy/scipy/issues/15765#issuecomment-1875564522
#      49 from scipy import linalg  # noqa: F401
# ---> 50 from . import distributions
#      51 from . import _mstats_basic as mstats_basic
#      52
#      53 from ._stats import _kendall_dis, _toint64, _weightedrankedtau
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\scipy\stats\distributions.py:10
#       1 #
#       2 # Author:  Travis Oliphant  2002-2011 with contributions from
#       3 #          SciPy Developers 2004-2011
#    (...)      6 #       instead of `git blame -Lxxx,+x`.
#       7 #
#       8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)  # noqa: F401
# ---> 10 from . import _continuous_distns
#      11 from . import _discrete_distns
#      13 from ._continuous_distns import *  # noqa: F403
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\scipy\stats\_continuous_distns.py:13
#       9 import operator
#      10
#      11 import numpy as np
#      12 from numpy.polynomial import Polynomial
# ---> 13 from scipy.interpolate import BSpline
#      14 from scipy._lib.doccer import (extend_notes_in_docstring,
#      15                                replace_notes_in_docstring,
#      16                                inherit_docstring_from)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\scipy\interpolate\__init__.py:192
#       1 """
#       2 ========================================
#       3 Interpolation (:mod:`scipy.interpolate`)
#    (...)    190
#     191 """  # noqa: E501
# --> 192 from ._interpolate import *
#     193 from ._fitpack_py import *
#     195 from ._fitpack2 import *
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\scipy\interpolate\_interpolate.py:21
#      19 from . import _fitpack_py
#      20 from ._polyint import _Interpolator1D
# ---> 21 from . import _ppoly
#      22 from ._interpnd import _ndim_coords_from_arrays
#      23 from ._bsplines import make_interp_spline, BSpline
#
# File <frozen importlib._bootstrap>:645, in ModuleSpec.parent(self)
# --> 645 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt:
